# %%
# %matplotlib inline

# %% [markdown]
# # LAB # - Template
#
# MARI4600/BIO5600: Ecosystem Modelling for Aquaculture (Dalhousie University)
#
# ----------------------------------------
#
# **Rendered link:** http://nbviewer.jupyter.org/urls/bitbucket.org/Diego_Ibarra/aquaculturemodelling2017/raw/tip/Week6/LAB%206%20-%20SHELL-E%20NPZD2%20Embayment%20with%20Oxygen.ipynb
#
# --------------------------------------

# %% [markdown]
# ### Setup of workspace
#
# <span class="important"></span> Make sure all required files are in the working directory:
#
# * Create a **folder** on the "Desktop" and name it <span class='file'>Lab6</span>
# * From Brightspace, download the following files into your new folder <span class='file'>Desktop\Lab6</span>:
#    * <span class='file'>model_NPZD2_SHELLE.py</span>
#
# * In Spyder, change the "working directory" to: <span class='file'>Desktop\Lab6</span>. Note that to change the "working directory", click on "folder icon" on top-right corner.
#
# ----------------------------------

# %% [markdown]
# <div class="Q"><br>
#
# Question goes here.
#
# <br><br><div class="qhelp"></div></div>

# %% [markdown]
# <span class="c2c"></span>
# <div class="c2c"></div>
# -----------------------------
# <span class="run"></span>
# <div class="run"></div>
# -----------------------------
# <span class="runcell"></span>
# <div class="runcell"></div>
# -----------------------------
# <span class="file">Text</span>
# <div class="file">Text</div>
# -----------------------------
# <span class="important"></span>
# <div class="important"></div>
# -----------------------------
# <span class="note"></span>
# <div class="note"></div>
# -----------------------------
# <span class="checkpoint">Text</span>
# <div class="checkpoint">Text</div>
# -----------------------------
# <span class="codeerror">Text</span>
# <div class="codeerror">Text</div>
# -----------------------------
# <span class="lineerror">Text</span>
# <div class="lineerror">Text</div>
# -----------------------------
# <span class="terminal"></span>
# <div class="terminal"></div>
# -----------------------------
# <span class="terminalBlock">Text</span>
# <div class="terminalBlock">Text</div>
# -----------------------------

# %% [markdown]
# <span class="c2c"></span>
# <div class="c2c"></div>
# -----------------------------
# <span class="run"></span>
# <div class="run"></div>
# -----------------------------
# <span class="runcell"></span>
# <div class="runcell"></div>
# -----------------------------
# <span class="file">Text</span>
# <div class="file">Text</div>
# -----------------------------
# <span class="important"></span>
# <div class="important"></div>
# -----------------------------
# <span class="note"></span>
# <div class="note"></div>
# -----------------------------
# <span class="checkpoint">Text</span>
# <div class="checkpoint">Text</div>
# -----------------------------
# <span class="codeerror">Text</span>
# <div class="codeerror">Text</div>
# -----------------------------
# <span class="lineerror">Text</span>
# <div class="lineerror">Text</div>
# -----------------------------
# <span class="terminal"></span>
# <div class="terminal"></div>
# -----------------------------
# <span class="terminalBlock">Text</span>
# <div class="terminalBlock">Text</div>
# -----------------------------

# %% [markdown]
# _Please beware that this model was designed as a teaching tool and may not be adequate to represent realistic applications_.
#
# # **This is the end of lab**
#
# *******************
# *******************
#
# Code below is for formatting of this lab. Do not alter!

# %%
# Loads css file and applies it to lab HTML
from IPython.core.display import HTML
def css():
    style = open("../css/custom.css", "r").read()
    return HTML(style)
css()
# Out:
# <style>
#
# body {
#   counter-reset: question_num;                     /* Set a counter named 'section', and it`s initial value is 0. */
# }
#
# /* Question Box */
# .Q {
#     background-color:#ff9900;
#     color:black;
#     font-size:17px;
#     width:100%;
#     border:1px solid #666666;
#     padding:5px;
# }
#
# .Q::before {
#     counter-increment: question_num;
#     content: "QUESTION " counter(question_num) '\A';
#     white-space: pre;
# }
#
# .qhelp {
#     color:#666666;
#     font-size:15px
# }
#
# .qhelp::after {
#     content: "Answer this question in the corresponding Brightspace LAB quiz"
# }
#
#
#
# /* code */
# .rendered_html pre, .rendered_html code {
#     font-family: "SF Mono","Segoe UI Mono","Roboto Mono","Ubuntu Mono",Menlo,Courier,monospace;
#     padding: 1px 3px;
#     border: 1px solid #e6e6e6;
#     border-radius: 3px;
#     background: #e6e6e6;
#     font-size: 12px;
#     line-height: 1.4;
#     color: #0052CC;
# }
#
#
# /* Copy to CONSOLE */
# ...
